# %% [markdown]
# <a href="https://colab.research.google.com/github/AdrianoHKim/Soulcode/blob/main/dashboards.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dashboard sobre a capacidade instalada e geração por ano

# %% [markdown]
# Dataset:<br>
# dados_backup_2_1_cap_instalada_por_regiao_e_uf_tratado.xlsx
#
# <br>
# Dashboard para visualizar a distribuição de capacidade instalada e geração de energia por região no Brasil.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Dashboard sobre a variação anual de capacidade instalada(MW)

# %% [markdown]
# Datasets:<br>
# dados_backup_2_2_cap_instalada_de_geracao_eletrica_por_fonte_mw.csv<br>
# dados_backup_2_3_geracao_eletrica_por_fonte_gwh_tratado.xlsx
#
# <br>
# Dashboard para visualizar a capacidade instalada(MW) por região e por fonte geradora e seus crescimentos anuais. Além da taxa de crescimento no período de 3 anos, das fontes: Solar, Eólica e Hidreletrica.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Dashboard sobre Usinas geradoras de energia(Solar e Eólica)

# %% [markdown]
# Dataset:<br>
# dados_backup_fator_capacidade_mwh_2015_2023.csv
#
# <br>
# Dashboard focado em uma das perguntas de negócio, aprofundando nas energias renováveis com maior ascenção, que mostra a distribuição geográfica das usinas solares e eólicas(geração centralizada) e a quantidade total de usinas(2023).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Dashboard sobre as energias renováveis em ascenção.

# %% [markdown]
# Dataset:<br>
# dados_backup_fator_capacidade_mwh_2015_2023.csv
#
# <br>
# Dashboard que mostra a distribuição geográfica da capacidade instalada das energias eólica e solar, por região, que responde também a pergunta de negócio, sobre qual região possui a maior capacidade instalada e geração.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Dashboard sobre regiões com maior potencial de geração de energia solar

# %% [markdown]
# Dataset:<br>
# dados_backup_global_horizontal_means.csv
#
# <br>
# Este Dashboard confirma as informações anteriores, mostrando graficamente as regiões que possuem maior potencial de incidência solar em comparação com a localização das usinas solares.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Dashboard sobre Geração Distribuída

# %% [markdown]
# Dataset:<br>
# dados_backup_tratado_geracao_distribuida.csv
#
# <br>
# Dashboard sobre a geração distribuída por fonte solar, que mostra o crescimento por região, por ano e as regiões com maior quantidade de empreendimentos de geração distribuída. Aqui iniciamos a apresentação de uma oportunidade, em relação com a pergunta de negócio.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Dashboard sobre pontos de recarga de veículos elétricos

# %% [markdown]
# Dataset:<br>
# dados_backup_iea_ponto_recarga_tratado.csv
#
# <br>
# Este Dashboard mostra o crescimento anual da quantidade de eletropontos no mundo, e a proporção de pontos de carregamentos lento/rápido, para demonstrar a modernização ao longo dos anos e uma possível oportunidade de negócio, que pode usar a energia solar como fonte geradora.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Dashboard sobre veículos elétricos

# %% [markdown]
# Dataset:<br>
# dados_backup_iea_veiculos_tratado.csv

# %% [markdown]
# Para complementar as informações sobre eletropontos e a oportunidade que ela representa, mostramos no dashboard abaixo o crescimento anual de veiculos elétricos e hibridos anualmente.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
