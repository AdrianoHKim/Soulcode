# %% [markdown]
# <a href="https://colab.research.google.com/github/squadOito/soulcodead2/blob/main/notebooks/fator_capacidade_mwh_2015_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Projeto Final**
# Escola: SoulCode Academy
#
# Curso: Bootcamp Analista de Dados - Martech - AD2
#
# **Alunos: Adriano Kim, José Aurelio, Marcos Paulo, Paulo Vitorino e Renato Costa e Wesley Luiz**
#
# Professores: Douglas Ribeiro, Franciane Rodrigues e Jonathas Carneiro

# %% [markdown]
# ## **Dicionário de dados**
#
# Obs.: descrever o PORQUE nao alteramos tanto o dicionario!!!

# %% [markdown]
# * id_subsistema - Identificador do subsistema
# * nom_subsistema - Nome do subsistema
# * id_estado - Sigla do Estado
# * nom_estado - Nome do Estado
# * nom_pontoconexao - Nome do ponto de conexão da usina/conjunto
# * nom_localizacao - Localização da usina/conjunto, disponível apenas região Nordeste
# * val_latitudesecoletora  - Latitude da usina/conjunto
# * val_longitudesecoletora - Longitude da usina/conjunto
# * val_latitudepontoconexao - Latitude do Ponto de Conexão
# * val_longitudepontoconexao - Longitude do Ponto de Conexão
# * nom_modalidadeoperacao - Modalidade de operação
# * nom_tipousina - Tipo da usina
# * nom_usina_conjunto - Nome da usina/conjunto
# * din_instante  - Data e hora
# * id_ons - Identificador da usina ou conjunto no ONS
# * ceg - Código Único do Empreendimento de Geração (CEG), estabelecido pela ANEEL
# * val_geracaoprogramada - Geração Programada, em MWmed(relação entre a eletricidade gerada em MWh e o tempo de funcionamento das instalações).
# * val_geracaoverificada - Geração Verificada, em MWmed(relação entre a eletricidade gerada em MWh e o tempo de funcionamento das instalações).
# * val_capacidadeinstalada - Capacidade instalada, em MW(MegaWatts)
# * val_fatorcapacidade - Fator de capacidade, obtida pela relação entre a geração e a capacidade instalada
#
#
# Fonte:
# *  https://dados.ons.org.br/dataset/fator-capacidade-2/resource/142f9c3b-4feb-492e-a0b4-bce97f059fca

# %% [markdown]
# # Extração
# A primeira etapa da ETL é a extração dos dados de sua fonte original. Dependendo do tipo de dados e da fonte, você pode precisar de diferentes ferramentas e técnicas para extrair os dados.

# %% [markdown]
# ## Instalações de Bibliotecas
# Instalações e importações das bibliotecas necessárias para o processo de ETL.

# %%
# !pip install gcsfs
# Out:
# Requirement already satisfied: gcsfs in /usr/local/lib/python3.10/dist-packages (2023.6.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from gcsfs) (3.8.5)
# Requirement already satisfied: decorator>4.1.2 in /usr/local/lib/python3.10/dist-packages (from gcsfs) (4.4.2)
# Requirement already satisfied: fsspec==2023.6.0 in /usr/local/lib/python3.10/dist-packages (from gcsfs) (2023.6.0)
# Requirement already satisfied: google-auth>=1.2 in /usr/local/lib/python3.10/dist-packages (from gcsfs) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib in /usr/local/lib/python3.10/dist-packages (from gcsfs) (1.0.0)
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.10/dist-packages (from gcsfs) (2.8.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from gcsfs) (2.31.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs) (3.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs) (1.3.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.2->gcsfs) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.2->gcsfs) (0.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.2->gcsfs) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.2->gcsfs) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib->gcsfs) (1.3.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage->gcsfs) (2.11.1)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage->gcsfs) (2.3.3)
# Requirement already satisfied: google-resumable-media>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage->gcsfs) (2.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->gcsfs) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->gcsfs) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->gcsfs) (2023.7.22)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage->gcsfs) (1.60.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage->gcsfs) (3.20.3)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.10/dist-packages (from google-resumable-media>=2.3.2->google-cloud-storage->gcsfs) (1.5.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.2->gcsfs) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gcsfs) (3.2.2)

# %%
# !pip install pandera
# Out:
# Collecting pandera
#   Downloading pandera-0.16.1-py3-none-any.whl (201 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.6/201.6 kB 3.6 MB/s eta 0:00:00
# Collecting multimethod (from pandera)
#   Downloading multimethod-1.9.1-py3-none-any.whl (10 kB)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from pandera) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from pandera) (23.1)
# Requirement already satisfied: pandas>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from pandera) (1.5.3)
# Collecting pydantic<2.0.0 (from pandera)
#   Downloading pydantic-1.10.12-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 21.5 MB/s eta 0:00:00
# Collecting typeguard>=3.0.2 (from pandera)
#   Downloading typeguard-4.1.0-py3-none-any.whl (33 kB)
# Collecting typing-inspect>=0.6.0 (from pandera)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from pandera) (1.14.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.0->pandera) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.0->pandera) (2023.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<2.0.0->pandera) (4.7.1)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect>=0.6.0->pandera)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.2.0->pandera) (1.16.0)
# Installing collected packages: typeguard, pydantic, mypy-extensions, multimethod, typing-inspect, pandera
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.1.1
#     Uninstalling pydantic-2.1.1:
#       Successfully uninstalled pydantic-2.1.1
# Successfully installed multimethod-1.9.1 mypy-extensions-1.0.0 pandera-0.16.1 pydantic-1.10.12 typeguard-4.1.0 typing-inspect-0.9.0

# %%
# Importando Bibliotecas pré instaladas
import os
import pandas as pd
import numpy as np
import pandera as pa
from google.cloud import storage
from google.colab import drive

# %%
# Ignorando alguns alertas desnecessários
import warnings
warnings.filterwarnings("ignore")

# %%
# Configuração da quantidade de colunas para aparecer em um DataFrame
pd.set_option('display.max_columns',100)

# %%
# Conexão com a conta do Google Cloud
serviceAccount = '/content/projeto-final-ad2-e8-ae566c3a2c2b.json'
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = serviceAccount

# %%
# Conexão com a bucket do Google Cloud

client = storage.Client()
bucket = client.get_bucket('projeto-final-ad2-e8')
bucket.blob('FATOR_CAPACIDADE_2015a2023_bruto.csv')
path = 'gs://projeto-final-ad2-e8/dados/brutos/csv/FATOR_CAPACIDADE_2015a2023_bruto.csv'

# %%
# Leitura e configuração dos arquivos extraidos
df_fator_cap = pd.read_csv(path,
                 sep=';',
                 encoding='UTF-8')

# %% [markdown]
# ## Pré Análise

# %%
# Visualização geral
df_fator_cap
# Out:
#         id_subsistema        nom_subsistema id_estado nom_estado  \
# 0                  NE              Nordeste        BA      BAHIA
# 1                  NE              Nordeste        BA      BAHIA
# 2                  NE              Nordeste        BA      BAHIA
# 3                  NE              Nordeste        BA      BAHIA
# 4                  NE              Nordeste        BA      BAHIA
# ...               ...                   ...       ...        ...
# 8622775            SE  Sudeste/Centro-Oeste        SP  SAO PAULO
# 8622776            SE  Sudeste/Centro-Oeste        SP  SAO PAULO
# 8622777            SE  Sudeste/Centro-Oeste        SP  SAO PAULO
# 8622778            SE  Sudeste/Centro-Oeste        SP  SAO PAULO
# 8622779            SE  Sudeste/Centro-Oeste        SP  SAO PAULO
#
#                    nom_pontoconexao nom_localizacao  val_latitudesecoletora  \
# 0            IGAPORA II - 69 kV (A)        Interior              -14.208409
# 1           IGAPORA II - 230 kV (B)        Interior              -14.102794
# 2           IGAPORA II - 230 kV (B)        Interior              -14.186292
# 3            IGAPORA II - 69 kV (A)        Interior              -13.916364
# 4            IGAPORA II - 69 kV (A)        Interior              -14.172142
# ...                             ...             ...                     ...
# 8622775    TRES IRMAOS - 138 kV (A)             NaN              -20.790444
# 8622776        DRACENA - 138 kV (A)             NaN              -21.450214
# 8622777       GETULINA - 138 kV (A)             NaN              -21.893809
# 8622778  AGUA VERMELHA - 138 kV (A)             NaN              -20.195849
# 8622779    TRES IRMAOS - 138 kV (A)             NaN              -20.620000
#
#          val_longitudesecoletora  val_latitudepontoconexao  \
# 0                     -42.636807                -14.027222
# 1                     -42.609369                -14.027222
# 2                     -42.493356                -14.027222
# 3                     -42.616201                -14.027222
# 4                     -42.598414                -14.027222
# ...                          ...                       ...
# 8622775               -51.529266                -20.656389
# 8622776               -51.587776                -21.457222
# 8622777               -49.863684                -21.855464
# 8622778               -50.032683                -19.867222
# 8622779               -51.300000                -20.656389
#
#          val_longitudepontoconexao nom_modalidadeoperacao nom_tipousina  \
# 0                       -42.629444     Conjunto de Usinas        Eólica
# 1                       -42.629444     Conjunto de Usinas        Eólica
# 2                       -42.629444     Conjunto de Usinas        Eólica
# 3                       -42.629444     Conjunto de Usinas        Eólica
# 4                       -42.629444     Conjunto de Usinas        Eólica
# ...                            ...                    ...           ...
# 8622775                 -51.482778     Conjunto de Usinas         Solar
# 8622776                 -51.526667     Conjunto de Usinas         Solar
# 8622777                 -49.838358     Conjunto de Usinas         Solar
# 8622778                 -50.350000     Conjunto de Usinas         Solar
# 8622779                 -51.482778     Conjunto de Usinas         Solar
#
#              nom_usina_conjunto      id_ons ceg         din_instante  \
# 0                Conj. Alvorada   CJU_BAALV   -  2015-01-01 00:00:00
# 1                  Conj. Araçás   CJU_BAARA   -  2015-01-01 00:00:00
# 2             Conj. Caetité 123   CJU_BACAE   -  2015-01-01 00:00:00
# 3        Conj. Curva dos Ventos   CJU_BACVN   -  2015-01-01 00:00:00
# 4                 Conj. Guirapá   CJU_BAGRP   -  2015-01-01 00:00:00
# ...                         ...         ...  ..                  ...
# 8622775          Conj. Castilho  CJU_SPCST3   -  2023-08-01 23:00:00
# 8622776           Conj. Dracena   CJU_SPUFD   -  2023-08-01 23:00:00
# 8622777           Conj. Guaimbê  CJU_SPCUFG   -  2023-08-01 23:00:00
# 8622778      Conj. Pedranópolis   CJU_SPPED   -  2023-08-01 23:00:00
# 8622779   Conj. Pereira Barreto    CJU_SPPB   -  2023-08-01 23:00:00
#
#          val_geracaoprogramada  val_geracaoverificada  \
# 0                         35.5              36.092073
# 1                         29.0              65.187220
# 2                         23.0              36.777401
# 3                         11.5              19.176730
# 4                         27.5              34.876650
# ...                        ...                    ...
# 8622775                    0.0               0.137000
# 8622776                    0.0               0.000000
# 8622777                    0.0               0.000000
# 8622778                    0.0               0.000000
# 8622779                    0.0               0.000000
#
#          val_capacidadeinstalada  val_fatorcapacidade
# 0                          38.40             0.939898
# 1                         107.22             0.607976
# 2                          90.00             0.408638
# 3                          54.05             0.354796
# 4                          52.80             0.660543
# ...                          ...                  ...
# 8622775                   210.70             0.000650
# 8622776                    81.00             0.000000
# 8622777                   150.00             0.000000
# 8622778                    90.36             0.000000
# 8622779                   203.52             0.000000
#
# [8622780 rows x 20 columns]

# %%
# Visualização de forma aleatoria
df_fator_cap.sample(3)
# Out:
#         id_subsistema nom_subsistema id_estado           nom_estado  \
# 5653838            NE       Nordeste        BA                BAHIA
# 4910801            NE       Nordeste        BA                BAHIA
# 7957343            NE       Nordeste        RN  RIO GRANDE DO NORTE
#
#               nom_pontoconexao nom_localizacao  val_latitudesecoletora  \
# 5653838  BARREIRAS - 69 kV (A)        Interior              -12.051321
# 4910801   TABOCAS - 230 kV (A)        Interior              -12.604269
# 7957343    J. CAMARA III138kVA         Litoral               -5.254889
#
#          val_longitudesecoletora  val_latitudepontoconexao  \
# 5653838               -45.597810                -12.131944
# 4910801               -44.083244                -12.583053
# 7957343               -35.849083                 -5.377281
#
#          val_longitudepontoconexao nom_modalidadeoperacao nom_tipousina  \
# 5653838                 -44.945556     Conjunto de Usinas         Solar
# 4910801                 -44.106708     Conjunto de Usinas         Solar
# 7957343                 -35.887215     Conjunto de Usinas        Eólica
#
#                    nom_usina_conjunto     id_ons ceg         din_instante  \
# 5653838  Conj. Sertão Solar Barreiras  CJU_BASSB   -  2021-09-03 01:00:00
# 4910801               Conj. Horizonte  CJU_BAHZT   -  2021-01-29 02:00:00
# 7957343        Conj. Brisa Potiguar I  CJU_RNBP1   -  2023-03-12 12:00:00
#
#          val_geracaoprogramada  val_geracaoverificada  \
# 5653838                    0.0                  0.000
# 4910801                    0.0                  0.000
# 7957343                    0.0                  2.468
#
#          val_capacidadeinstalada  val_fatorcapacidade
# 5653838                    94.64             0.000000
# 4910801                    77.40             0.000000
# 7957343                   183.60             0.013442

# %%
# Tamanho total de (linhas , colunas)
df_fator_cap.shape
# Out:
# (8622780, 20)

# %%
# Todos os tipos de dados presentes
df_fator_cap.dtypes
# Out:
# id_subsistema                 object
# nom_subsistema                object
# id_estado                     object
# nom_estado                    object
# nom_pontoconexao              object
# nom_localizacao               object
# val_latitudesecoletora       float64
# val_longitudesecoletora      float64
# val_latitudepontoconexao     float64
# val_longitudepontoconexao    float64
# nom_modalidadeoperacao        object
# nom_tipousina                 object
# nom_usina_conjunto            object
# id_ons                        object
# ceg                           object
# din_instante                  object
# val_geracaoprogramada        float64
# val_geracaoverificada        float64
# val_capacidadeinstalada      float64
# val_fatorcapacidade          float64
# dtype: object

# %%
# Contagem de observações para cada coluna
df_fator_cap.count()
# Out:
# id_subsistema                8622780
# nom_subsistema               8622780
# id_estado                    8622780
# nom_estado                   8622780
# nom_pontoconexao             8553255
# nom_localizacao              7420235
# val_latitudesecoletora       8610132
# val_longitudesecoletora      8610132
# val_latitudepontoconexao     8485411
# val_longitudepontoconexao    8485411
# nom_modalidadeoperacao       8622780
# nom_tipousina                8622780
# nom_usina_conjunto           8622780
# id_ons                       8622780
# ceg                          8622780
# din_instante                 8622780
# val_geracaoprogramada        8278267
# val_geracaoverificada        8622780
# val_capacidadeinstalada      8578982
# val_fatorcapacidade          8622780
# dtype: int64

# %%
# Informações detalhadas
df_fator_cap.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8622780 entries, 0 to 8622779
# Data columns (total 20 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   id_subsistema              object
#  1   nom_subsistema             object
#  2   id_estado                  object
#  3   nom_estado                 object
#  4   nom_pontoconexao           object
#  5   nom_localizacao            object
#  6   val_latitudesecoletora     float64
#  7   val_longitudesecoletora    float64
#  8   val_latitudepontoconexao   float64
#  9   val_longitudepontoconexao  float64
#  10  nom_modalidadeoperacao     object
#  11  nom_tipousina              object
#  12  nom_usina_conjunto         object
#  13  id_ons                     object
#  14  ceg                        object
#  15  din_instante               object
#  16  val_geracaoprogramada      float64
#  17  val_geracaoverificada      float64
#  18  val_capacidadeinstalada    float64
#  19  val_fatorcapacidade        float64
# dtypes: float64(8), object(12)
# memory usage: 1.3+ GB

# %%
# Fazendo um relatório para mostrar os valores únicos de cada atributo.
# O for vai garantir que a atividade seja feita automaticamente para todos os atributos

for coluna in df_fator_cap:
    valor = (df_fator_cap[coluna].unique())
    print("-"*70)
    msg = f"Valores únicos para o atributo {coluna}:"
    print(f"{msg:^70}")
    print("-"*70)
    print(f"\n{valor}\n")
    print("-"*70)
# Out:
# ----------------------------------------------------------------------
#             Valores únicos para o atributo id_subsistema:
# ----------------------------------------------------------------------
#
# ['NE' 'S' 'N' 'SE']
#
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
#             Valores únicos para o atributo nom_subsistema:
# ----------------------------------------------------------------------
#
# ['Nordeste' 'Sul' 'Norte' 'Sudeste/Centro-Oeste']
#
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
#               Valores únicos para o atributo id_estado:
# ----------------------------------------------------------------------
#
# ['BA' 'CE' 'RN' 'RS' 'SC' 'PE' 'PI' 'MA' 'MG' 'SP' 'PB']
#
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
#               Valores únicos para o atributo nom_estado:
# ----------------------------------------------------------------------
#
# ['BAHIA' 'CEARA' 'RIO GRANDE DO NORTE' 'RIO GRANDE DO SUL'
#  'SANTA CATARINA' 'PERNAMBUCO' 'PIAUI' 'MARANHAO' 'MINAS GERAIS'
#  'SAO PAULO' 'PARAIBA']
#
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
#            Valores únicos para o atributo nom_pontoconexao:
# ----------------------------------------------------------------------
#
# ['IGAPORA II - 69 kV (A)' 'IGAPORA II - 230 kV (B)'
#  'ACARAU II - 69 kV (A)' 'SOBRAL III - 230 kV (A)' 'ACU II - 230 kV (A)'
#  'MOSSORO II - 230 kV (A)' 'J. CAMARA III138kVA' 'JOAO CAMARA 269kVA'
#  'J. CAMARA II - 230 kV (A)' 'OSORIO 2 - 69 kV (A)'
#  'OSORIO 2 - 230 kV (A)' 'CERRO CHATO - 230 kV (A)' 'QUINTA - 138 kV (A)'
#  'QUINTA - 69 kV (A)' 'S V PALMAR 2 - 525 kV (A)' 'AQUIBATA - 138 kV (A)'
#  'RIO DO OURO138kVA' 'TACARATU - 230 kV (A)' 'ATLANTIDA 2 - 69 kV (A)'
#  'CHAPADA II230kVA' 'U.SOBRADINHO - 230 kV (A)'
#  'GARANHUNS II - 230 kV (A)' 'CAMPO FORMOSO - 230 kV (A)'
#  'PECEM II - 230 kV (A)' 'CHAPADA I230kVA' 'PINDAI II - 69 kV (A)'
#  'CHAPADA III230kVA' 'ACARAU II - 230 kV (A)' 'IRECE - 230 kV (A)'
#  'LAGOA NOVA II - 69 kV (A)' 'MORRO CHAPEU2 - 230 kV (A)' nan
#  'IBIAPINA II - 69 kV (A)' 'CURRAL PIAUI II230kVA'
#  'MARMELEIRO 2 - 525 kV (A)' 'VIAMAO 3 - 230 kV (A)'
#  'BROT.MACAUBAS - 230 kV (A)' 'RUSSAS II - 230 kV (A)'
#  'POLO GUAMARE - 138 kV (A)' 'EXTREMOZ II - 230 kV (A)'
#  'B.JESUS LAPA - 69 kV (A)' 'MIRANDA II500kVA' 'B.JESUS LAPA - 230 kV (A)'
#  'TOUROS - 69 kV (A)' 'TABOCAS - 230 kV (A)' 'SE BONITO138kVA'
#  'BRUMADO II - 230 kV (A)' 'PIRAPORA 2 - 138 kV (C)'
#  'MORRO CHAPEU2 - 69 kV (A)' 'JUAZEIRO II - 230 kV (A)'
#  'S.JOAO PIAUI - 500 kV (A)' 'MOSSORO IV - 230 kV (A)'
#  'ACU II - 138 kV (A)' 'GETULINA - 138 kV (A)' 'IBIAPINA II - 230 kV (A)'
#  'COREMAS230kVA' 'OUROLANDIA II - 230 kV (A)' 'TOUROS - 230 kV (A)'
#  'S.JOAO PIAUI230kVA' 'QUIXERE - 230 kV (A)' 'PARACATU 4 - 500 kV (A)'
#  'AQUIRAZ II - 69 kV (A)' 'COL BOA HORA138kVA' 'GENTIO OURO II230kVA'
#  'PINDAI II - 230 kV (A)' 'DRACENA - 138 kV (A)' 'BARREIRAS - 69 kV (A)'

#
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
#                 Valores únicos para o atributo id_ons:
# ----------------------------------------------------------------------
#
# ['CJU_BAALV' 'CJU_BAARA' 'CJU_BACAE' 'CJU_BACVN' 'CJU_BAGRP' 'CJU_BALAL'
#  'CJU_BAMOR' 'CJU_BANSC' 'CJU_BAPNT' 'CJU_CEPPG' 'CEUCZ' 'CEUFM' 'RNUAU'
#  'RNUAD' 'CJU_RNCAD' 'CJU_RNMAC' 'CJU_RNMOD' 'CJU_RNMVD' 'CJU_RNMVT'
#  'CJU_RNREN' 'CJU_RNSTC' 'CJU_RNUVT' 'RNUES3' 'RNUERU' 'RNUERT' 'RSUECI'
#  'CJU_RSACA' 'CJU_RSCCH' 'CJU_RSQ138' 'CJU_RSQ69' 'CJU_RSSVPA'
#  'CJU_SCCEAD' 'CJU_SCCEBJ' 'CJU_RNSAB' 'CJU_RNREV' 'CJU_PETAT' 'CJU_RNODA'
#  'RSUEXG' 'CJU_RNBP1' 'CJU_PICP2' 'CJU_BAPBR' 'CJU_BACTA' 'CJU_PECE2'
#  'CJU_BACFO' 'CJU_CETRA' 'CJU_PICH1' 'CJU_PEPAR' 'CJU_RNAMZ' 'CJU_BACTE'
#  'CJU_BAPEL' 'CJU_PICP3' 'CJU_CEITC' 'CJU_BAGOI' 'CJU_RNCA1' 'CJU_RNCA2'
#  'CJU_RNSS2' 'CJU_RNSS3' 'CJU_BABW1' 'CJU_BABW2' 'CJU_RNCDV' 'CJU_RNBFJ'
#  'CJU_PECLE' 'CJU_BASAZ' 'CJU_PISBA' 'CJU_RNBSL' 'CJU_CESRO' 'CEEMAU'
#  'CJU_RNCPD' 'CJU_PIAR3' 'CJU_RNCA3' 'CJU_RSMRO2' 'CJU_RSVIA3' 'CJU_BABMC'
#  'CJU_CEAUD' 'CJU_CEARD' 'CJU_CEICR' 'CJU_CETBA' 'CJU_RNABR' 'CJU_RNMSC'
#  'CJU_RNRIA' 'CJU_BABJU' 'CJU_CEFSA' 'CJU_RSLBA' 'CJU_MAPLN' 'CJU_BALAP'
#  'CJU_RNCNB' 'CJU_BATBV' 'CJU_CECHE' 'CJU_BAVDB' 'CJU_BACRL' 'CJU_PICPH'
#  'CJU_MGCPIR' 'CJU_BACRI' 'CJU_BADFN' 'CJU_PINVO' 'CJU_BACND' 'CJU_RNFLO'
#  'CJU_CESTI' 'RNFVAE' 'CJU_SPCUFG' 'CJU_BABJL' 'CJU_BAMCS' 'CJU_BAHZT'
#  'CJU_CECBS' 'CEECVA' 'CJU_PBRAL' 'CJU_BACLA' 'CJU_BAVB2' 'CJU_BASPD'
#  'CJU_RNCUT' 'CJU_PILDB' 'CJU_BABAB' 'CJU_CEPTM' 'CJU_BASDB' 'CJU_CECAL'
#  'CJU_MGPTU4' 'CJU_BAJZS' 'CJU_BAUBN' 'CJU_CESDF' 'CJU_SPUFBH' 'CJU_BALRA'
#  'CJU_BAGPX' 'CJU_SPUFD' 'CJU_RNSMG' 'CJU_BASSB' 'CJU_PISGO' 'CJU_RNSDM'
#  'CJU_PISJP' 'CJU_CEJAN' 'CJU_BAFLS' 'CJU_PILDV1' 'CJU_PILDV2'
#  'CJU_PILDV3' 'CJU_BAFLA' 'CJU_RNMNR' 'CJU_BAARI' 'CJU_CESER' 'CJU_BACLA2'
#  'CJU_RNAVD' 'CJU_PISGOA' 'CJU_RNSM2A' 'CJU_RNSDMA' 'CJU_RNSDMB'
#  'CJU_RNGAM' 'CJU_RNTSN' 'CJU_PEBRI' 'CJU_RNRDV' 'CJU_RNSM2B' 'CJU_PBCHSD'
#  'CJU_RNCMR' 'CJU_RNSMN' 'CJU_BASSD' 'CJU_BAMS2' 'CJU_SPPB' 'CJU_PBCHS'
#  'CJU_CEUFAL' 'CJU_MGUJAI' 'CJU_RNSDMX' 'CJU_RNFIG' 'CJU_PEFVD'
#  'CJU_BAJZS2' 'CJU_PBCHN' 'CJU_BAVB3' 'CJU_PILB2' 'CJU_BAABL' 'CJU_BAFDS'
#  'CEFFDM' 'CJU_MGFSA' 'CJU_BATBD' 'CJU_RNAFB' 'CJU_BATUC' 'CJU_BAMS2A'
#  'CJU_BAMS2B' 'CJU_CESEM' 'CJU_CESERA' 'CJU_BAIGD' 'CJU_PIVDP3'
#  'CJU_MGJAN' 'CJU_PISR0B' 'CJU_CELAV' 'CJU_PIOIT' 'CJU_PBLZA' 'CJU_BAABD'
#  'CJU_BAQUN' 'CJU_BASVT' 'CJU_PIVSR' 'CJU_RNJDA' 'CJU_MGUFLS' 'CJU_BAVSE'
#  'CJU_PIVDP2' 'CJU_RNEMVD' 'CJU_BABBS' 'CJU_BATBR' 'CJU_SPPED' 'CJU_RNJER'
#  'CJU_MGSDC' 'CJU_RNSDMC' 'CJU_PBCSDS' 'CJU_PILDV' 'CJU_RNRVE'
#  'CJU_SPCST3' 'CJU_RNANE' 'CJU_MGARX' 'CJU_BAEMS2' 'CJU_CEESTI'
#  'CJU_PEETAT' 'CJU_PILBI' 'CJU_PISBAE' 'CJU_PEFTAT' 'CJU_PIFSBA'
#  'CJU_RNSAG' 'CJU_CEFSEM' 'CJU_PECIR' 'CJU_RNCAJ1' 'CJU_RNACA' 'CJU_BATQN'
#  'CJU_BAFFUT' 'CJU_MGUFPU' 'CJU_MGVZPQ' 'CJU_RNJDT' 'CJU_PEBELM'
#  'CJU_BACAN']
#
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
#                  Valores únicos para o atributo ceg:
# ----------------------------------------------------------------------
#
# ['-' 'EOL.CV.CE.028699-0.01' 'EOL.CV.CE.028631-1.01'
#  'EOL.CV.RN.028444-0.01' 'EOL.CV.RN.028443-2.01' 'EOL.CV.RN.030339-9.01'
#  'EOL.CV.RN.030416-6.01' 'EOL.CV.RN.030417-4.01' 'EOL.CV.RS.028712-1.01'
#  'EOL.CV.RS.031302-5.01' 'EOL.CV.CE.030841-2.01' 'UFV.RS.RN.034184-3.01'
#  'EOL.CV.CE.033756-0.01' 'UFV.RS.CE.047255-7.01']
#
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
#              Valores únicos para o atributo din_instante:
# ----------------------------------------------------------------------
#
# ['2015-01-01 00:00:00' '2015-01-01 01:00:00' '2015-01-01 02:00:00' ...
#  '2023-08-01 21:00:00' '2023-08-01 22:00:00' '2023-08-01 23:00:00']
#
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
#         Valores únicos para o atributo val_geracaoprogramada:
# ----------------------------------------------------------------------
#
# [ 35.5  29.   23.  ... 740.5 719.  710. ]
#
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
#         Valores únicos para o atributo val_geracaoverificada:
# ----------------------------------------------------------------------
#
# [ 36.09207257  65.18722     36.77740101 ... 665.916      370.294
#  229.083     ]
#
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
#          Valores únicos para o atributo val_fatorcapacidade:
# ----------------------------------------------------------------------
#
# [0.93989772 0.60797631 0.40863779 ... 0.23817188 0.25555003 0.20048062]
#
# ----------------------------------------------------------------------

# %% [markdown]
# # Transformação
# Aqui os dados extraídos precisam ser transformados em um formato adequado para análise, e para isso deve seguir alguns passos, que podem precisar serem repetidos ao longo do processo de análise.

# %% [markdown]
# ## Limpeza de Dados
# Remover dados duplicados, corrigir erros de digitação, tratar dados inconsistentes etc.

# %%
# Verificar se há valores duplicados
df_fator_cap.duplicated()
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 8622775    False
# 8622776    False
# 8622777    False
# 8622778    False
# 8622779    False
# Length: 8622780, dtype: bool

# %%
# Verificar se há valores nulos/ausentes
df_fator_cap.isnull().sum()
# Out:
# id_subsistema                      0
# nom_subsistema                     0
# id_estado                          0
# nom_estado                         0
# nom_pontoconexao               69525
# nom_localizacao              1202545
# val_latitudesecoletora         12648
# val_longitudesecoletora        12648
# val_latitudepontoconexao      137369
# val_longitudepontoconexao     137369
# nom_modalidadeoperacao             0
# nom_tipousina                      0
# nom_usina_conjunto                 0
# id_ons                             0
# ceg                                0
# din_instante                       0
# val_geracaoprogramada         344513
# val_geracaoverificada              0
# val_capacidadeinstalada        43798
# val_fatorcapacidade                0
# dtype: int64

# %%
# Calcular a porcentagem de valores nulos em cada coluna
porcentagem_nulos = (df_fator_cap.isnull().sum() / len(df_fator_cap)) * 100

# Exibir a porcentagem de valores nulos em cada coluna
print(round(porcentagem_nulos,2))
# Out:
# id_subsistema                 0.00
# nom_subsistema                0.00
# id_estado                     0.00
# nom_estado                    0.00
# nom_pontoconexao              0.81
# nom_localizacao              13.95
# val_latitudesecoletora        0.15
# val_longitudesecoletora       0.15
# val_latitudepontoconexao      1.59
# val_longitudepontoconexao     1.59
# nom_modalidadeoperacao        0.00
# nom_tipousina                 0.00
# nom_usina_conjunto            0.00
# id_ons                        0.00
# ceg                           0.00
# din_instante                  0.00
# val_geracaoprogramada         4.00
# val_geracaoverificada         0.00
# val_capacidadeinstalada       0.51
# val_fatorcapacidade           0.00
# dtype: float64

# %%
df_fator_cap_backup = df_fator_cap.copy()

# %% [markdown]
# ## Normalização de Dados
# Colocar os dados em um formato padronizado para facilitar a análise.

# %% [markdown]
# ### Tipagem

# %%
# criando um dataset para validar a tipagem
df_data_alterada = df_fator_cap_backup.copy()

# %%
# Convertendo para data e hora, preservando as horas
df_data_alterada['din_instante'] = pd.to_datetime(df_data_alterada['din_instante'], exact=False)

# %%
# Verificando se foi efetivado a alteração
df_data_alterada.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8622780 entries, 0 to 8622779
# Data columns (total 20 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   id_subsistema              object
#  1   nom_subsistema             object
#  2   id_estado                  object
#  3   nom_estado                 object
#  4   nom_pontoconexao           object
#  5   nom_localizacao            object
#  6   val_latitudesecoletora     float64
#  7   val_longitudesecoletora    float64
#  8   val_latitudepontoconexao   float64
#  9   val_longitudepontoconexao  float64
#  10  nom_modalidadeoperacao     object
#  11  nom_tipousina              object
#  12  nom_usina_conjunto         object
#  13  id_ons                     object
#  14  ceg                        object
#  15  din_instante               datetime64[ns]
#  16  val_geracaoprogramada      float64
#  17  val_geracaoverificada      float64
#  18  val_capacidadeinstalada    float64
#  19  val_fatorcapacidade        float64
# dtypes: datetime64[ns](1), float64(8), object(11)
# memory usage: 1.3+ GB

# %%
# Garantindo que a tipagem não modificou a informação do registro
df_fator_cap_backup.din_instante[10000]
# Out:
# '2015-01-13 14:00:00'

# %%
# Garantindo que a tipagem não modificou a informação do registro
df_data_alterada.din_instante[10000]
# Out:
# Timestamp('2015-01-13 14:00:00')

# %%
# Convertendo para data e hora, preservando as horas. No dataframe de backup
df_fator_cap_backup['din_instante'] = pd.to_datetime(df_fator_cap_backup['din_instante'], exact=False)

# %%
# Verificando se foi efetivado a alteração
df_fator_cap_backup.dtypes
# Out:
# id_subsistema                        object
# nom_subsistema                       object
# id_estado                            object
# nom_estado                           object
# nom_pontoconexao                     object
# nom_localizacao                      object
# val_latitudesecoletora              float64
# val_longitudesecoletora             float64
# val_latitudepontoconexao            float64
# val_longitudepontoconexao           float64
# nom_modalidadeoperacao               object
# nom_tipousina                        object
# nom_usina_conjunto                   object
# id_ons                               object
# ceg                                  object
# din_instante                 datetime64[ns]
# val_geracaoprogramada               float64
# val_geracaoverificada               float64
# val_capacidadeinstalada             float64
# val_fatorcapacidade                 float64
# dtype: object

# %%
# Examinando alteração
df_fator_cap_backup.dtypes
# Out:
# id_subsistema                        object
# nom_subsistema                       object
# id_estado                            object
# nom_estado                           object
# nom_pontoconexao                     object
# nom_localizacao                      object
# val_latitudesecoletora              float64
# val_longitudesecoletora             float64
# val_latitudepontoconexao            float64
# val_longitudepontoconexao           float64
# nom_modalidadeoperacao               object
# nom_tipousina                        object
# nom_usina_conjunto                   object
# id_ons                               object
# ceg                                  object
# data                         datetime64[ns]
# val_geracaoprogramada               float64
# val_geracaoverificada               float64
# val_capacidadeinstalada             float64
# val_fatorcapacidade                 float64
# dtype: object

# %% [markdown]
# ## **Qualidade e integridade dos dados**

# %% [markdown]
# ### **Validação da estrutura dos dados (schema)**

# %%
# Verifica se há qualquer valor nulo ou nao numerico(NaN)
df_fator_cap_backup.isna().any()
# Out:
# id_subsistema                False
# nom_subsistema               False
# id_estado                    False
# nom_estado                   False
# nom_pontoconexao              True
# nom_localizacao               True
# val_latitudesecoletora        True
# val_longitudesecoletora       True
# val_latitudepontoconexao      True
# val_longitudepontoconexao     True
# nom_modalidadeoperacao       False
# nom_tipousina                False
# nom_usina_conjunto           False
# id_ons                       False
# ceg                          False
# data                         False
# val_geracaoprogramada         True
# val_geracaoverificada        False
# val_capacidadeinstalada       True
# val_fatorcapacidade          False
# dtype: bool

# %%
# Lista das colunas a serem preenchidas
colunas_preenchimento = [
    'nom_pontoconexao',
    'nom_localizacao',
    'val_latitudesecoletora',
    'val_longitudesecoletora',
    'val_latitudepontoconexao',
    'val_longitudepontoconexao',
    'val_geracaoprogramada',
    'val_capacidadeinstalada'
]

# Loop para preenchimento de colunas com 'NA' ou 0
for coluna in colunas_preenchimento:
    if 'val_' in coluna:
        valor_preenchimento = 0
    else:
        valor_preenchimento = 'NA'
    df_fator_cap_backup[coluna].fillna(valor_preenchimento, inplace=True)

# %%
df_fator_cap_backup.dtypes
# Out:
# id_subsistema                        object
# nom_subsistema                       object
# id_estado                            object
# nom_estado                           object
# nom_pontoconexao                     object
# nom_localizacao                      object
# val_latitudesecoletora              float64
# val_longitudesecoletora             float64
# val_latitudepontoconexao            float64
# val_longitudepontoconexao           float64
# nom_modalidadeoperacao               object
# nom_tipousina                        object
# nom_usina_conjunto                   object
# id_ons                               object
# ceg                                  object
# data                         datetime64[ns]
# val_geracaoprogramada               float64
# val_geracaoverificada               float64
# val_capacidadeinstalada             float64
# val_fatorcapacidade                 float64
# dtype: object

# %%
df_fator_cap_backup.columns
# Out:
# Index(['id_subsistema', 'nom_subsistema', 'id_estado', 'nom_estado',
#        'nom_pontoconexao', 'nom_localizacao', 'val_latitudesecoletora',
#        'val_longitudesecoletora', 'val_latitudepontoconexao',
#        'val_longitudepontoconexao', 'nom_modalidadeoperacao', 'nom_tipousina',
#        'nom_usina_conjunto', 'id_ons', 'ceg', 'data', 'val_geracaoprogramada',
#        'val_geracaoverificada', 'val_capacidadeinstalada',
#        'val_fatorcapacidade'],
#       dtype='object')

# %%
# Definindo o esquema de validação e o examinando
schema = pa.DataFrameSchema({
    'id_subsistema': pa.Column(pa.String),
    'nom_subsistema': pa.Column(pa.String),
    'id_estado': pa.Column(pa.String),
    'nom_estado': pa.Column(pa.String),
    'nom_pontoconexao': pa.Column(pa.String),
    'nom_localizacao': pa.Column(pa.String),
    'val_latitudesecoletora': pa.Column(pa.Float),
    'val_longitudesecoletora': pa.Column(pa.Float),
    'val_latitudepontoconexao': pa.Column(pa.Float),
    'val_longitudepontoconexao': pa.Column(pa.Float),
    'nom_modalidadeoperacao': pa.Column(pa.String),
    'nom_tipousina': pa.Column(pa.String),
    'nom_usina_conjunto': pa.Column(pa.String),
    'id_ons': pa.Column(pa.String),
    'ceg': pa.Column(pa.String),
    'data': pa.Column(pa.DateTime),
    'val_geracaoprogramada': pa.Column(pa.Float),
    'val_geracaoverificada': pa.Column(pa.Float),
    'val_capacidadeinstalada': pa.Column(pa.Float),
    'val_fatorcapacidade': pa.Column(pa.Float)
})

schema.validate(df_fator_cap_backup)
# Out:
#         id_subsistema        nom_subsistema id_estado nom_estado  \
# 0                  NE              Nordeste        BA      BAHIA
# 1                  NE              Nordeste        BA      BAHIA
# 2                  NE              Nordeste        BA      BAHIA
# 3                  NE              Nordeste        BA      BAHIA
# 4                  NE              Nordeste        BA      BAHIA
# ...               ...                   ...       ...        ...
# 8622775            SE  Sudeste/Centro-Oeste        SP  SAO PAULO
# 8622776            SE  Sudeste/Centro-Oeste        SP  SAO PAULO
# 8622777            SE  Sudeste/Centro-Oeste        SP  SAO PAULO
# 8622778            SE  Sudeste/Centro-Oeste        SP  SAO PAULO
# 8622779            SE  Sudeste/Centro-Oeste        SP  SAO PAULO
#
#                    nom_pontoconexao nom_localizacao  val_latitudesecoletora  \
# 0            IGAPORA II - 69 kV (A)        Interior              -14.208409
# 1           IGAPORA II - 230 kV (B)        Interior              -14.102794
# 2           IGAPORA II - 230 kV (B)        Interior              -14.186292
# 3            IGAPORA II - 69 kV (A)        Interior              -13.916364
# 4            IGAPORA II - 69 kV (A)        Interior              -14.172142
# ...                             ...             ...                     ...
# 8622775    TRES IRMAOS - 138 kV (A)              NA              -20.790444
# 8622776        DRACENA - 138 kV (A)              NA              -21.450214
# 8622777       GETULINA - 138 kV (A)              NA              -21.893809
# 8622778  AGUA VERMELHA - 138 kV (A)              NA              -20.195849
# 8622779    TRES IRMAOS - 138 kV (A)              NA              -20.620000
#
#          val_longitudesecoletora  val_latitudepontoconexao  \
# 0                     -42.636807                -14.027222
# 1                     -42.609369                -14.027222
# 2                     -42.493356                -14.027222
# 3                     -42.616201                -14.027222
# 4                     -42.598414                -14.027222
# ...                          ...                       ...
# 8622775               -51.529266                -20.656389
# 8622776               -51.587776                -21.457222
# 8622777               -49.863684                -21.855464
# 8622778               -50.032683                -19.867222
# 8622779               -51.300000                -20.656389
#
#          val_longitudepontoconexao nom_modalidadeoperacao nom_tipousina  \
# 0                       -42.629444     Conjunto de Usinas        Eólica
# 1                       -42.629444     Conjunto de Usinas        Eólica
# 2                       -42.629444     Conjunto de Usinas        Eólica
# 3                       -42.629444     Conjunto de Usinas        Eólica
# 4                       -42.629444     Conjunto de Usinas        Eólica
# ...                            ...                    ...           ...
# 8622775                 -51.482778     Conjunto de Usinas         Solar
# 8622776                 -51.526667     Conjunto de Usinas         Solar
# 8622777                 -49.838358     Conjunto de Usinas         Solar
# 8622778                 -50.350000     Conjunto de Usinas         Solar
# 8622779                 -51.482778     Conjunto de Usinas         Solar
#
#              nom_usina_conjunto      id_ons ceg                data  \
# 0                Conj. Alvorada   CJU_BAALV   - 2015-01-01 00:00:00
# 1                  Conj. Araçás   CJU_BAARA   - 2015-01-01 00:00:00
# 2             Conj. Caetité 123   CJU_BACAE   - 2015-01-01 00:00:00
# 3        Conj. Curva dos Ventos   CJU_BACVN   - 2015-01-01 00:00:00
# 4                 Conj. Guirapá   CJU_BAGRP   - 2015-01-01 00:00:00
# ...                         ...         ...  ..                 ...
# 8622775          Conj. Castilho  CJU_SPCST3   - 2023-08-01 23:00:00
# 8622776           Conj. Dracena   CJU_SPUFD   - 2023-08-01 23:00:00
# 8622777           Conj. Guaimbê  CJU_SPCUFG   - 2023-08-01 23:00:00
# 8622778      Conj. Pedranópolis   CJU_SPPED   - 2023-08-01 23:00:00
# 8622779   Conj. Pereira Barreto    CJU_SPPB   - 2023-08-01 23:00:00
#
#          val_geracaoprogramada  val_geracaoverificada  \
# 0                         35.5              36.092073
# 1                         29.0              65.187220
# 2                         23.0              36.777401
# 3                         11.5              19.176730
# 4                         27.5              34.876650
# ...                        ...                    ...
# 8622775                    0.0               0.137000
# 8622776                    0.0               0.000000
# 8622777                    0.0               0.000000
# 8622778                    0.0               0.000000
# 8622779                    0.0               0.000000
#
#          val_capacidadeinstalada  val_fatorcapacidade
# 0                          38.40             0.939898
# 1                         107.22             0.607976
# 2                          90.00             0.408638
# 3                          54.05             0.354796
# 4                          52.80             0.660543
# ...                          ...                  ...
# 8622775                   210.70             0.000650
# 8622776                    81.00             0.000000
# 8622777                   150.00             0.000000
# 8622778                    90.36             0.000000
# 8622779                   203.52             0.000000
#
# [8622780 rows x 20 columns]

# %%
df_fator_cap_backup.count()
# Out:
# id_subsistema                8622780
# nom_subsistema               8622780
# id_estado                    8622780
# nom_estado                   8622780
# nom_pontoconexao             8622780
# nom_localizacao              8622780
# val_latitudesecoletora       8622780
# val_longitudesecoletora      8622780
# val_latitudepontoconexao     8622780
# val_longitudepontoconexao    8622780
# nom_modalidadeoperacao       8622780
# nom_tipousina                8622780
# nom_usina_conjunto           8622780
# id_ons                       8622780
# ceg                          8622780
# data                         8622780
# val_geracaoprogramada        8622780
# val_geracaoverificada        8622780
# val_capacidadeinstalada      8622780
# val_fatorcapacidade          8622780
# dtype: int64

# %%
# Extraindo o ano da coluna 'data'
df_fator_cap_backup['ano'] = df_fator_cap_backup['data'].dt.year

# Agrupando por 'nom_subsistema' e 'ano', somando os valores e resetando o índice
df_agrupado = df_fator_cap_backup.groupby(['nom_subsistema', 'ano'])['val_geracaoverificada'].sum().reset_index()

# Calculando o crescimento percentual em relação ao ano anterior
df_agrupado['crescimento_percentual'] = df_agrupado.groupby('nom_subsistema')['val_geracaoverificada'].pct_change() * 100

# Exibindo o DataFrame final
print(df_agrupado)
# Out:
#           nom_subsistema   ano  val_geracaoverificada  crescimento_percentual
# 0               Nordeste  2015           1.143166e+07                     NaN
# 1               Nordeste  2016           2.192146e+07               91.761012
# 2               Nordeste  2017           3.318455e+07               51.379267
# 3               Nordeste  2018           4.086911e+07               23.157038
# 4               Nordeste  2019           4.895535e+07               19.785713
# 5               Nordeste  2020           4.959941e+07                1.315602
# 6               Nordeste  2021           6.611422e+07               33.296384
# 7               Nordeste  2022           7.787436e+07               17.787613
# 8               Nordeste  2023           5.059694e+07              -35.027466
# 9                  Norte  2017           6.451276e+05                     NaN
# 10                 Norte  2018           1.033454e+06               60.193682
# 11                 Norte  2019           1.650591e+06               59.715996
# 12                 Norte  2020           1.583159e+06               -4.085318
# 13                 Norte  2021           1.744918e+06               10.217466
# 14                 Norte  2022           1.606555e+06               -7.929481
# 15                 Norte  2023           6.977839e+05              -56.566440
# 16  Sudeste/Centro-Oeste  2017           1.047681e+05                     NaN
# 17  Sudeste/Centro-Oeste  2018           9.105220e+05              769.083272
# 18  Sudeste/Centro-Oeste  2019           1.523551e+06               67.327215
# 19  Sudeste/Centro-Oeste  2020           1.757405e+06               15.349294
# 20  Sudeste/Centro-Oeste  2021           1.968575e+06               12.016006
# 21  Sudeste/Centro-Oeste  2022           3.381567e+06               71.777382
# 22  Sudeste/Centro-Oeste  2023           3.954883e+06               16.954144
# 23                   Sul  2015           2.624462e+06                     NaN
# 24                   Sul  2016           3.780547e+06               44.050325
# 25                   Sul  2017           5.576707e+06               47.510609
# 26                   Sul  2018           5.665221e+06                1.587198
# 27                   Sul  2019           5.618601e+06               -0.822915
# 28                   Sul  2020           6.362243e+06               13.235361
# 29                   Sul  2021           6.173630e+06               -2.964569
# 30                   Sul  2022           5.948238e+06               -3.650874
# 31                   Sul  2023           2.897960e+06              -51.280364

# %% [markdown]
# ## Visualização

# %%
import plotly.express as px
import pandas as pd

# Supondo que você já possui o DataFrame df_agrupado com as colunas 'nom_subsistema', 'ano' e 'val_geracaoverificada'

# Criando o gráfico com Plotly
fig = px.line(df_agrupado, x='ano', y='val_geracaoverificada', color='nom_subsistema')

# Personalizando o layout do gráfico
fig.update_layout(
    title='Soma do Valor de Geração Verificada por Ano',
    xaxis_title='Ano',
    yaxis_title='Soma do Valor de Geração Verificada',
    legend_title='Região',
    showlegend=True,
    xaxis=dict(showgrid=True),
    yaxis=dict(showgrid=True)
)

# Exibindo o gráfico
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b90ee32b-72de-4c58-88e4-2d8549349a4a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b90ee32b-72de-4c58-88e4-2d8549349a4a")) {                    Plotly.newPlot(                        "b90ee32b-72de-4c58-88e4-2d8549349a4a",                        [{"hovertemplate":"nom_subsistema=Nordeste\u003cbr\u003eano=%{x}\u003cbr\u003eval_geracaoverificada=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Nordeste","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Nordeste","orientation":"v","showlegend":true,"x":[2015,2016,2017,2018,2019,2020,2021,2022,2023],"xaxis":"x","y":[11431657.5860846,21921462.26282797,33184548.913,40869107.395,48955351.73923,49599409.256,66114218.9345,77874360.0615,50596944.696],"yaxis":"y","type":"scatter"},{"hovertemplate":"nom_subsistema=Norte\u003cbr\u003eano=%{x}\u003cbr\u003eval_geracaoverificada=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Norte","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Norte","orientation":"v","showlegend":true,"x":[2017,2018,2019,2020,2021,2022,2023],"xaxis":"x","y":[645127.572,1033453.611,1650590.73,1583158.85,1744917.567,1606554.664,697783.884],"yaxis":"y","type":"scatter"},{"hovertemplate":"nom_subsistema=Sudeste\u002fCentro-Oeste\u003cbr\u003eano=%{x}\u003cbr\u003eval_geracaoverificada=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sudeste\u002fCentro-Oeste","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Sudeste\u002fCentro-Oeste","orientation":"v","showlegend":true,"x":[2017,2018,2019,2020,2021,2022,2023],"xaxis":"x","y":[104768.094,910521.979,1523551.073,1757405.402,1968575.337,3381567.169,3954882.95],"yaxis":"y","type":"scatter"},{"hovertemplate":"nom_subsistema=Sul\u003cbr\u003eano=%{x}\u003cbr\u003eval_geracaoverificada=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sul","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Sul","orientation":"v","showlegend":true,"x":[2015,2016,2017,2018,2019,2020,2021,2022,2023],"xaxis":"x","y":[2624462.35873257,3780546.566,5576707.249,5665220.644,5618600.68,6362242.738,6173629.633,5948238.17,2897959.956],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[ ...

# %%
# Backup para analise
df_fator_cap_tratado = df_fator_cap_backup.copy()

# %% [markdown]
# # Carregamento
# Depois que os dados são extraídos e transformados adequadamente, eles estarão prontos para as análise, mas antes disso eles precisam ser carregados em um local de armazenamento adequado. Podendo ser um banco de dados SQL ou NoSQL, um sistema de armazenamento em nuvem, e para o caso de disponibilizar o projeto publicamente é ideal que ele seja colocar em uma pasta de datasets, diferenciando o arquivo bruto e o tratado.

# %%
# Upando para o Google Cloud

 df_fator_cap_tratado.to_csv('gs://projeto-final-ad2-e8/dados/tratados/fator_capacidade_mwh_2015_2023.csv', index=False)

# %% [markdown]
# # Análise exploratória de dados.
# - Descrição de dados: identificação dos tipos de variáveis, dimensões dos dados, valores extremos e estatísticas descritivas.
# - Visualização dos dados: criação de gráficos, tabelas e outros tipos de visualização para entender a distribuição e a relação entre as variáveis.
# - Identificação de padrões: identificação de padrões, tendências, correlações e outras relações entre as variáveis.
# - Testes estatísticos: aplicação de testes estatísticos para confirmar ou refutar hipóteses sobre os dados.

# %% [markdown]
# ## Instalações de bibliotecas
# bibliotecas necessárias para a análise de dados que não haviam sido importadas anteriormente.

# %% [markdown]
# ## **Estatisticas**

# %%
# Resumo de estatisticas descritivas
df_fator_cap_tratado.describe().round(2)
# Out:
#        val_latitudesecoletora  val_longitudesecoletora  \
# count              8622780.00               8622780.00
# mean                   -10.51                   -40.78
# std                      7.77                     4.99
# min                    -33.47                   -55.71
# 25%                    -13.92                   -42.61
# 50%                     -7.96                   -40.64
# 75%                     -5.15                   -36.58
# max                      0.00                     0.00
#
#        val_latitudepontoconexao  val_longitudepontoconexao  \
# count                8622780.00                 8622780.00
# mean                     -10.48                     -40.26
# std                        7.79                       6.96
# min                      -33.47                     -55.71
# 25%                      -14.03                     -42.63
# 50%                       -8.03                     -40.48
# 75%                       -5.38                     -36.91
# max                        0.00                       0.00
#
#        val_geracaoprogramada  val_geracaoverificada  val_capacidadeinstalada  \
# count             8622780.00             8622780.00               8622780.00
# mean                   50.99                  54.25                   138.76
# std                    59.41                  64.43                   100.14
# min                     0.00                   0.00                     0.00
# 25%                    10.50                   9.67                    70.00
# 50%                    34.00                  35.06                   105.60
# 75%                    68.50                  73.98                   183.60
# max                   759.50                2697.73                  1020.36
#
#        val_fatorcapacidade         ano
# count           8622780.00  8622780.00
# mean                  0.38     2019.78
# std                   0.31        2.29
# min                   0.00     2015.00
# 25%                   0.10     2018.00
# 50%                   0.34     2020.00
# 75%                   0.64     2022.00
# max                  12.19     2023.00

# %%
# Correlações de todas colunas quantitativas
df_fator_cap_tratado.corr()
# Out:
#                            val_latitudesecoletora  val_longitudesecoletora  \
# val_latitudesecoletora                   1.000000                 0.880945
# val_longitudesecoletora                  0.880945                 1.000000
# val_latitudepontoconexao                 0.991299                 0.859697
# val_longitudepontoconexao                0.656412                 0.679027
# val_geracaoprogramada                    0.017163                 0.009443
# val_geracaoverificada                    0.008085                 0.002068
# val_capacidadeinstalada                 -0.065237                -0.091826
# val_fatorcapacidade                      0.048579                 0.071567
# ano                                      0.068680                 0.040052
#
#                            val_latitudepontoconexao  \
# val_latitudesecoletora                     0.991299
# val_longitudesecoletora                    0.859697
# val_latitudepontoconexao                   1.000000
# val_longitudepontoconexao                  0.731745
# val_geracaoprogramada                      0.016534
# val_geracaoverificada                      0.007114
# val_capacidadeinstalada                   -0.070763
# val_fatorcapacidade                        0.046642
# ano                                        0.064455
#
#                            val_longitudepontoconexao  val_geracaoprogramada  \
# val_latitudesecoletora                      0.656412               0.017163
# val_longitudesecoletora                     0.679027               0.009443
# val_latitudepontoconexao                    0.731745               0.016534
# val_longitudepontoconexao                   1.000000               0.003711
# val_geracaoprogramada                       0.003711               1.000000
# val_geracaoverificada                      -0.003389               0.880517
# val_capacidadeinstalada                    -0.087966               0.579620
# val_fatorcapacidade                         0.036743               0.528874
# ano                                         0.009651               0.082458
#
#                            val_geracaoverificada  val_capacidadeinstalada  \
# val_latitudesecoletora                  0.008085                -0.065237
# val_longitudesecoletora                 0.002068                -0.091826
# val_latitudepontoconexao                0.007114                -0.070763
# val_longitudepontoconexao              -0.003389                -0.087966
# val_geracaoprogramada                   0.880517                 0.579620
# val_geracaoverificada                   1.000000                 0.568397
# val_capacidadeinstalada                 0.568397                 1.000000
# val_fatorcapacidade                     0.661020                 0.019408
# ano                                     0.066972                 0.176298
#
#                            val_fatorcapacidade       ano
# val_latitudesecoletora                0.048579  0.068680
# val_longitudesecoletora               0.071567  0.040052
# val_latitudepontoconexao              0.046642  0.064455
# val_longitudepontoconexao             0.036743  0.009651
# val_geracaoprogramada                 0.528874  0.082458
# val_geracaoverificada                 0.661020  0.066972
# val_capacidadeinstalada               0.019408  0.176298
# val_fatorcapacidade                   1.000000 -0.072286
# ano                                  -0.072286  1.000000
